# %%
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np

# %%
v2_traj = pd.read_csv("v2data1.csv")
x = v2_traj["Downrange"]
y = v2_traj["Altitude"]
plt.plot(x,y)

# %%
hu1alt = pd.read_csv("huey\hu1pidtuning0.csv")
t = hu1alt["Time"]
signal = hu1alt["Altitude"]
setpoint = hu1alt["Setpoint"]

plt.plot(t,signal, color ='r')
plt.plot(t, setpoint, 'k')
plt.show()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\h'
# <>:1: SyntaxWarning: invalid escape sequence '\h'
# C:\Users\verci\AppData\Local\Temp\ipykernel_3636\908531024.py:1: SyntaxWarning: invalid escape sequence '\h'
#   hu1alt = pd.read_csv("huey\hu1pidtuning0.csv")

# %%
hu1alt = pd.read_csv("huey\hu1pidtuning0.csv")
t = hu1alt["Time"]
signal = hu1alt["Altitude"]
setpoint = hu1alt["Setpoint"]

plt.plot(t,signal, color ='r')
plt.plot(t, setpoint, 'k')
plt.show()
